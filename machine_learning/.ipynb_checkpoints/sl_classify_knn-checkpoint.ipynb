# %% [markdown]
# # Sample Problem Solving

# %%
from sklearn import datasets
import pandas as pd
import seaborn as sns

# %%
# possible datasets in sklearn
dsets = [i for i in dir(datasets) if i.startswith('load_')]
dsets
# Out:
# ['load_boston',
#  'load_breast_cancer',
#  'load_diabetes',
#  'load_digits',
#  'load_files',
#  'load_iris',
#  'load_linnerud',
#  'load_mlcomp',
#  'load_sample_image',
#  'load_sample_images',
#  'load_svmlight_file',
#  'load_svmlight_files',
#  'load_wine']

# %%
wine = datasets.load_wine()
wine.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# ## Do some EDA

# %%
# lets do some EDA

wine_df = pd.DataFrame(wine.data, columns=wine.feature_names)
wine_df.head(3)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0

# %%
wine_df.shape
# Out:
# (178, 13)

# %%
sns.set()

_ = pd.plotting.scatter_matrix(wine_df, c=wine.target, s=5, marker='.', 
                     cmap='viridis', alpha=1, figsize=(10, 9))

# %%
Knn().info()
# Out:
# Reminder!
# 	+ Data as NumPy array or pandas DF
# 	+ CANNOT contain MISSING data
# 	+ Feature & target values same length

# %%
c_methods = [f for f in dir(Knn) if not f.startswith('__')]
c_methods
# Out:
# ['complexity_curve', 'info']

# %%
from supervised.classification.scripts import Knn

# %%
Knn().info()
# Out:
# Reminder!
# 	+ Data as NumPy array or pandas DF
# 	+ CANNOT contain MISSING data
# 	+ Feature & target values same length
#
# Class methods:
# 	+ complexity_curve
# 	+ decision_boundry
# 	+ info

# %%
a = Knn()
a.complexity_curve(X=wine.data, y=wine.target, stratify=wine.target, max_neighbors=40)

# %%
X = wine.data[:, :2]
y = wine.target

a.decision_boundry(X=X, y=y, n_neighbors=6)
